# %%
import sys
sys.path.append('../src')
import numpy as np
import matplotlib.pyplot as plt

from my_packages.lesCsv import TidsseriePlotter

temp_data = TidsseriePlotter('../data/temperatur.csv', 'temperatur')
# temp_data.behandle_data()
temp_data.vis_graf('år')
temp_data.mean_value()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       9 # temp_data.behandle_data()
#      10 temp_data.vis_graf('år')
# ---> 11 temp_data.mean_value()
#
# TypeError: TidsseriePlotter.mean_value() takes 0 positional arguments but 1 was given

# %%
import sys
sys.path.append('../src')

import numpy as np
import matplotlib.pyplot as plt
from my_packages.lesogplottCsv import TidsseriePlotter
sys.path.append('../src')
from my_packages.sammenligning import sammenlign_plot


# Kontrollpanel

#Valg av csv filer: temperatur.csv, Vannføring.csv
csvfilen = 'temperatur.csv'
Periode = 'dag'
Navn ='Temperatur'
Enhet = '°C'
graf_type = 'line'
#For å gjøre om enhet til noe annet
konverteringsfaktor = None

#Intervall
Slutt =None
Start = None

#True eller False (På eller av): Slår av eller på median og gjennomsnittsverdi (Mean)
Median = True
Mean = True

#Ekstremalpunkter, av eller på
MAX = True
MIN = True 


#Kode
temp_data = TidsseriePlotter('../data/'+csvfilen, enhet = Enhet, periode = Periode, visningsnavn = Navn, konvertering = konverteringsfaktor, slutt=Slutt, start = Start )
temp_data.vis_graf(median=Median, mean=Mean, maximum = MAX, minimum = MIN, minverdi=0.001)
temp_data2 = TidsseriePlotter('../data/'+csvfilen, enhet = Enhet, periode = 'uke', visningsnavn = Navn,graf_type='scatter', konvertering = konverteringsfaktor,slutt ='2024-01-01')
temp_data2.vis_graf(median=Median, mean=Mean, maximum = MAX, minimum = MIN)
# temp_data.bar()

# sammenlign_plot(temp_data, temp_data2,tittel='temperatur tidsplot dag/måned')
